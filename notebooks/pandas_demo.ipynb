# %%
from sqlalchemy import create_engine
import pandas

# %load_ext sql
# %sql postgresql+psycopg2://

df = pandas.read_sql(
    'Select * FROM country',
    create_engine("postgresql+psycopg2://")
)
df
# Out:
#      code                   name      capital               province  \
# 0      AL                Albania       Tirane                Albania
# 1      GR                 Greece       Athens                 Attiki
# 2      MK              Macedonia       Skopje              Macedonia
# 3     SRB                 Serbia     Belgrade                 Serbia
# 4     MNE             Montenegro    Podgorica             Montenegro
# ..    ...                    ...          ...                    ...
# 233    SD              Swaziland      Mbabane              Swaziland
# 234  REUN                Reunion  Saint-Denis                Reunion
# 235  HELX           Saint Helena    Jamestown           Saint Helena
# 236   STP  Sao Tome and Principe     Sao Tome  Sao Tome and Principe
# 237    SY             Seychelles     Victoria             Seychelles
#
#          area  population
# 0     28750.0   3249136.0
# 1    131940.0  10538594.0
# 2     25333.0   2104035.0
# 3     77474.0   7379339.0
# 4     14026.0    672180.0
# ..        ...         ...
# 233   17360.0    998730.0
# 234    2510.0    679198.0
# 235     413.0      7637.0
# 236    1001.0    144128.0
# 237     455.0     77575.0
#
# [238 rows x 6 columns]

# %%
df[ ['code'] ]
# Out:
#      code
# 0      AL
# 1      GR
# 2      MK
# 3     SRB
# 4     MNE
# ..    ...
# 233    SD
# 234  REUN
# 235  HELX
# 236   STP
# 237    SY
#
# [238 rows x 1 columns]

# %%
df[ df[ 'code'] == 'D']
# Out:
#    code     name capital province      area  population
# 11    D  Germany  Berlin   Berlin  356910.0  83536115.0

# %%
df.groupby('province').count()
# Out:
#                 code  name  capital  area  population
# province
# Abu Dhabi          1     1        1     1           1
# Afghanistan        1     1        1     1           1
# Ahal               1     1        1     1           1
# Albania            1     1        1     1           1
# Algeria            1     1        1     1           1
# ...              ...   ...      ...   ...         ...
# Western Sahara     1     1        1     1           1
# Yangon             1     1        1     1           1
# Yemen              1     1        1     1           1
# Zimbabwe           1     1        1     1           1
# al Khartum         1     1        1     1           1
#
# [233 rows x 5 columns]
